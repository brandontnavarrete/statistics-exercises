# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from pydataset import data
import scipy.stats as stats

import seaborn as sns
import random
random.seed(42)
# %matplotlib inline

# %%
import seaborn as sns
from math import sqrt

# %%
df = pd.read_csv('telco_normalized - telco_normalized.csv')

# %%
df.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents churn_month paperless_billing  \
# 0  Female               0     Yes        Yes         NaN               Yes
# 1    Male               0      No         No         NaN                No
# 2    Male               0      No         No  2022-01-31               Yes
# 3    Male               1     Yes         No  2022-01-31               Yes
# 4  Female               1     Yes         No  2022-01-31               Yes
#
# ...

# %%
# do those who churn (has_churned, boolean) spend more each month 
# (avg_monthly_spend, numeric) than those who do not churn? 
# (boolean x numeric: comparison of means (t-test) across the 2 groups)

# %% [markdown]
# # has the network latency gone up since we switched internet service providers?

# %%
# has latency speed (numeric) slowed down since isp (new_isp, boolean ) OR (year_of _switch, numeric)

# %%
# null = latency speed has no change  or decreased in relation to isp.

# alt = latency speed has a significant increase in speed in relation to isp

# speed and isp has a positive correlation and we verify true.

# speed and isp has a no / negative correlation and we verify true.

# type 1 error = latency did speed up but we don't attribute it to isp

# type 2 error = latency didn't speed up but we also say it did in relation to isp

# %% [markdown]
# # is the website redesign any good?

# %%
# since a specific date ( in relation to the website redesign) ( (date_of_switch, numeric))
#has our internet traffic increased.( new_click_through, numeric) vs ( old_click_through, numeric)

# %%
# null = the date of the redesign has no influence or lower in website traffic.

# alt = the date of the redesign has significant influence in website traffic.

# date and traffic has a positive correlation and we verify true.

# date and traffic has a no correlation or negative and we verify true.

# type 1 error = traffic has increased but we say it hasn't.

# type 2 error = traffic hasn't increased but we say it did.

# %% [markdown]
# # is our television ad driving more sales?

# %%
# since a specific date ( in relation to the ad release) ( (date_of_ad, numeric))
#has our internet traffic increased.( new_click_through, numeric) vs ( old_click_through, numeric)

# null = the television ad has no influence or lower sales

# alt = the television ad has influence or higher sales

# sales increased and we say it did

# sales decreased or stayed the same and we agree

# type 1 error = sales have increased but we say it hasn't

# type 2 error = sales have decreased but we say it hasn't

# %% [markdown]
# # Exercises T - Test

# %% [markdown]
# # Comparing Means

# %% [markdown]
# # # 1 Answer with the type of test you would use (assume normal distribution):

# %% [markdown]
# # Is there a difference in grades of students on the second floor compared to grades of all students?

# %%
# 1-sample (comparing 1 group to the average) t-test.

# %% [markdown]
# # Are adults who drink milk taller than adults who dont drink milk?

# %%
# independent T-Test (a.k.a. Two Sample T-Test)
# Compare mean of group a to mean of group b.

# %% [markdown]
# # is the the price of gas higher in texas or in new mexico?

# %%
# independent T-Test (a.k.a. Two Sample T-Test)
# Compare mean of group a to mean of group b.

# %% [markdown]
# # Are there differences in stress levels between students who take data science vs students who take web development vs students who take cloud academy?

# %%
# ANOVA Analysis of Variance
# Goal: Compare means of groups a, b & c.

# %% [markdown]
# # # 2 Ace Realty wants to determine whether the average time it takes to sell homes is different for its two offices. A sample of 40 sales from office #1 revealed a mean of 90 days and a standard deviation of 15 days. A sample of 50 sales from office #2 revealed a mean of 100 days and a standard deviation of 20 days. Use a .05 level of significance.

# %%
# prob distribution

# %%
# independent T-Test (a.k.a. Two Sample T-Test)
# null = there is no difference in the time it takes to sell between offices
# alt =  there is some difference in the time it takes to sell between offices

alpha = 0.05

# %%
office1 = stats.norm(90,15)
# (mean, std)
#normal distribution
office2 = stats.norm(100,20)

# %%
#  making my random values with the mean and std(from above)
d1 = office1.rvs(40)
d2 = office2.rvs(50)

# %%
d1.var()
# Out:
# 157.2111130523895

# %%
d2.var()
# Out:
# 426.5834338462786

# %%
stats.levene(d1,d2)
# Out:
# LeveneResult(statistic=10.37045941502463, pvalue=0.0017946880889995625)

# %%
t, p = stats.ttest_ind(d1, d2, equal_var = False)
t, p , alpha
# Out:
# (-1.2500665865237481, 0.21480422015861422, 0.05)

# %%
print("is p < alpha? ", p < alpha)
# Out:
# is p < alpha?  False

# %%
if p > alpha:
    print("We fail to reject $H_{0}$")
else:
    print("We reject $H_{0}$")
# Out:
# We fail to reject $H_{0}$

# %%
plt.plot(d1)
plt.plot(d2)

# %% [markdown]
# # load mpg data

# %%
mpg = data('mpg')

# %% [markdown]
# # Is there a difference in fuel-efficiency in cars from 2008 vs 1999?

# %%
# Ho = " there is no difference in fuel- eff from cars in 2008 vs 1999"
# Ha = " there is a difference in fuel-eff from cars in 2008 vs 1999"

# %%
alpha = .05

# %% [markdown]
# # building my columns

# %%
# finding the gas
mpg['ovr_all'] = (mpg['hwy'] + mpg['cty'])/2

# %%
mpg_08 = mpg[mpg['year'] == 2008]['ovr_all']

# %%
mpg_1999 = mpg[mpg['year'] == 1999]['ovr_all']

# %% [markdown]
# # exploring my data

# %%
mpg_08.count()
# Out:
# 117

# %%
mpg_08.var()
# Out:
# 24.097480106100797

# %%
mpg_1999.count()
# Out:
# 117

# %%
mpg_1999.var()
# Out:
# 27.122605363984682

# %% [markdown]
# # plot history

# %%
mpg_08.hist()
# Out:
# <AxesSubplot:>

# %%
mpg_1999.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # answer

# %%
t, p = stats.ttest_ind(mpg_08, mpg_1999, equal_var= False)
t, p , alpha
# Out:
# (-0.21960177245940962, 0.8263750772060638, 0.05)

# %%
if p > alpha:
    print("We fail to reject $H_{0}$")
else:
    print("Reject $H_{0}$")
# Out:
# We fail to reject $H_{0}$

# %%
# there is no noticeable  difference.

# %% [markdown]
# # Are compact cars more fuel-efficient than the average car?

# %%
# compact cars gas < avg car
# one sample of all cars

# %% [markdown]
# # building data`

# %%
mpg['compact'] = mpg['class'] == 'compact'
mpg[mpg['compact']].count()
# Out:
# manufacturer    47
# model           47
# displ           47
# year            47
# cyl             47
# trans           47
# drv             47
# cty             47
# hwy             47
# fl              47
# class           47
# ovr_all         47
# compact         47
# dtype: int64

# %%
compact_mpg_sample = mpg[mpg.compact == True ].ovr_all

#churn_sample = df[df.churn == 'Yes'].monthly_charges

# %%
compact_mpg_sample1 = pd.DataFrame(compact_mpg_sample)
compact_mpg_sample1
# Out:
#      ovr_all
# 1       23.5
# 2       25.0
# 3       25.5
# 4       25.5
# 5       21.0
# 6       22.0
# 7       22.5
# 8       22.0
# 9       20.5
# 10      24.0
# 11      23.0
# 12      20.0
# 13      21.0
# 14      21.0
# 15      20.0
# 142     25.0
# 143     23.0
# 170     22.5
# 171     23.5
# 172     22.0
# 173     23.5
# 187     24.0
# 188     25.0
# 189     26.0
# 190     26.5
# 191     22.0
# 192     22.0
# 193     22.5
# 194     27.0
# 195     28.5
# 196     30.5
# 197     32.5
# 198     30.5
# 208     25.0
# 209     22.5
# 210     25.0
# 211     25.5
# 212     20.5
# 213     38.5
# 214     25.0
# 215     22.5
# 216     25.5
# 217     25.0
# 218     25.0
# 219     25.0
# 220     19.5
# 221     20.5

# %%
mean = mpg['ovr_all'].mean()
mean
# Out:
# 20.14957264957265

# %% [markdown]
# # plot

# %%
plt.hist(compact_mpg_sample)
# Out:
# (array([ 9., 12., 14.,  7.,  1.,  2.,  1.,  0.,  0.,  1.]),
#  array([19.5, 21.4, 23.3, 25.2, 27.1, 29. , 30.9, 32.8, 34.7, 36.6, 38.5]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # answer

# %%
t, p = stats.ttest_1samp(compact_mpg_sample, mean)
t , p
# Out:
# (7.896888573132533, 4.198563794317163e-10)

# %%
print(t, p/2, alpha)
# Out:
# 7.896888573132533 2.0992818971585816e-10 0.05

# %%
if t < 0 and p/2 > alpha:  
    print("We fail to reject $H_{0}$")
else:
    print("We reject $H_{0}$")
# Out:
# We reject $H_{0}$

# %% [markdown]
# # Do manual cars get better gas mileage than automatic cars?

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    ovr_all  compact
# 1     23.5     True
# 2     25.0     True
# 3     25.5     True
# 4     25.5     True
# 5     21.0     True

# %%
mpg["is_auto"] = (mpg["trans"].str.startswith("a"))
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    ovr_all  compact  is_auto
# 1     23.5     True     True
# 2     25.0     True    False
# 3     25.5     True    False
# 4     25.5     True     True
# 5     21.0     True     True

# %%
# two samples of one population
# do man cars gas < auto cars gas

# %%
auto_gas_sample = mpg[mpg.is_auto == True ].ovr_all
plt.hist(auto_gas_sample)
# Out:
# (array([ 6., 35., 27., 20., 35., 18.,  9.,  4.,  2.,  1.]),
#  array([10.5 , 12.95, 15.4 , 17.85, 20.3 , 22.75, 25.2 , 27.65, 30.1 ,
#         32.55, 35.  ]),
#  <BarContainer object of 10 artists>)

# %%
man_gas_sample = mpg[mpg.is_auto == False ].ovr_all
plt.hist(man_gas_sample)
# Out:
# (array([ 1., 10.,  8., 22., 10., 19.,  4.,  1.,  0.,  2.]),
#  array([10.5, 13.4, 16.3, 19.2, 22.1, 25. , 27.9, 30.8, 33.7, 36.6, 39.5]),
#  <BarContainer object of 10 artists>)

# %%
man_gas_sample.count()
# Out:
# 77

# %%
auto_gas_sample.count()
# Out:
# 157

# %%
man_gas_sample.var()
# Out:
# 26.635167464114826

# %%
auto_gas_sample.var()
# Out:
# 21.942777233382337

# %%
t, p = stats.ttest_ind(man_gas_sample, auto_gas_sample, equal_var=False)
t, p
# Out:
# (4.443514012903072, 1.7952248999917893e-05)

# %%
print("is p/2 < alpha? ", p < alpha)
print("is t < 0? ", t < 0)
# Out:
# is p/2 < alpha?  True
# is t < 0?  False

# %%
if t > 0  and p/2 < alpha:
    print("reject $H_{0}$")

else:
    print("fail to reject $H_{0}$")
# Out:
# reject $H_{0}$

# %% [markdown]
# # Correlation

# %% [markdown]
# # Answer with the type of stats test you would use (assume normal distribution):

# %% [markdown]
# # Is there a relationship between the length of your arm and the length of your foot?

# %%
#corr, p = stats.pearsonr( len_of_arm , len_of_foot)
 # spearmans

# %% [markdown]
# # Do guys and gals quit their jobs at the same rate?

# %%
# use a independent T - test
# parametric

# %% [markdown]
# # Does the length of time of the lecture correlate with a students grade?

# %%
#corr, p = stats.pearsonr( len_of_arm , len_of_foot)
# spearmans

# %% [markdown]
# # Use the telco_churn data.

# %%
# select data

# %%
tel_churn = pd.read_csv('Telco-Customer-Churn.csv')
tel_churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
tel_churn.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
#  # Does tenure correlate with monthly charges?

# %%
# state hypothesis
# select the data 
# plot data
# normality
# run test
# draw conclusions

# %% [markdown]
# Ho = no linear correlation
#
# Ha = there is a linear correlation between tenure and monthly charges/

# %%
tel_churn.plot.scatter('tenure','MonthlyCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
# distrubutions of data

# %%
tel_churn.MonthlyCharges.hist()
tel_churn.tenure.hist()
# Out:
# <AxesSubplot:>

# %%
# therse are not normal distributions

# %%
r ,p = stats.spearmanr(tel_churn.tenure,tel_churn.MonthlyCharges)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:1.0271266876409408e-123

# %% [markdown]
# # Total charges?

# %% [markdown]
# Ho = there is no linear corr between total chargs and tenure
#
# Ha = there is a linear corr between total chargs and tenure

# %%
# state hypothesis
# select the data 
# plot data
# normality
# run test
# draw conclusions

# %%
# np.nan(tel_churn)

# %%
tel_churn['TotalCharges'] = tel_churn['TotalCharges'].astype('string')

# %%
tel_churn['TotalCharges'] = tel_churn['TotalCharges'].replace(' ','0')

# %%
tel_churn['TotalCharges']= tel_churn['TotalCharges'].astype('float')

# %%
tel_churn.TotalCharges.hist()
# Out:
# <AxesSubplot:>

# %%
tel_churn.tenure.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")

# %%
r,p = stats.spearmanr(tel_churn.tenure,tel_churn.TotalCharges)
r,p
# Out:
# (0.8896957900597577, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %% [markdown]
# ## What happens if you control for phone and internet service?

# %%
# state hypothesis
# select the data 
# plot data
# normality
# run test
# draw conclusions

# %% [markdown]
# # no phone service

# %% [markdown]
# Ho = of customers who have no phone service, there is no linear relationship
#
# Ha = of customers who have no phone service, there is a linear relationship

# %%
no_phone_tel_churn = tel_churn[tel_churn['PhoneService'] == "No"]

x = no_phone_tel_churn.tenure
y = no_phone_tel_churn.TotalCharges

# %%
plt.hist(no_phone_tel_churn.tenure)
plt.show()
plt.hist(no_phone_tel_churn.TotalCharges)
# Out:
# (array([230.,  89.,  72.,  59.,  61.,  48.,  48.,  29.,  24.,  22.]),
#  array([   0.  ,  491.97,  983.94, 1475.91, 1967.88, 2459.85, 2951.82,
#         3443.79, 3935.76, 4427.73, 4919.7 ]),
#  <BarContainer object of 10 artists>)

# %%
no_phone_tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
r,p = stats.spearmanr(no_phone_tel_churn.tenure,no_phone_tel_churn.TotalCharges)
r,p
# Out:
# (0.9794110522550499, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %% [markdown]
# # yes phone service

# %% [markdown]
# Ho = of customers who have phone service, there is no linear relationship
# Ha = of customers who have phone service, there is a linear relationship

# %%
yes_phone_tel_churn = tel_churn[tel_churn['PhoneService'] == "Yes"]

x1 = no_phone_tel_churn.tenure
y1 = no_phone_tel_churn.TotalCharges

# %%
plt.hist(yes_phone_tel_churn.tenure)
plt.show()
plt.hist(yes_phone_tel_churn.TotalCharges)
# Out:
# (array([2401., 1102.,  581.,  425.,  408.,  391.,  396.,  311.,  224.,
#          122.]),
#  array([   0.  ,  868.48, 1736.96, 2605.44, 3473.92, 4342.4 , 5210.88,
#         6079.36, 6947.84, 7816.32, 8684.8 ]),
#  <BarContainer object of 10 artists>)

# %%
yes_phone_tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
r,p = stats.spearmanr(yes_phone_tel_churn.tenure,yes_phone_tel_churn.TotalCharges)
r,p
# Out:
# (0.8866128497089706, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %%
tel_churn['InternetService'].unique()

# %% [markdown]
# # dsl customer

# %%
dsl_tel_churn = tel_churn[tel_churn['InternetService'] == "DSL"]

# %%
x2 = dsl_tel_churn.tenure
y2 = dsl_tel_churn.TotalCharges

# %% [markdown]
# # dsl total charges

# %%
plt.hist(dsl_tel_churn.tenure)
plt.show()
plt.hist(dsl_tel_churn.TotalCharges)
# Out:
# (array([781., 328., 267., 225., 195., 184., 155., 114., 102.,  70.]),
#  array([   0.   ,  685.905, 1371.81 , 2057.715, 2743.62 , 3429.525,
#         4115.43 , 4801.335, 5487.24 , 6173.145, 6859.05 ]),
#  <BarContainer object of 10 artists>)

# %%
dsl_tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
r,p = stats.spearmanr(dsl_tel_churn.tenure,dsl_tel_churn.TotalCharges)
r,p
# Out:
# (0.9711479815136296, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %%
plt.hist(dsl_tel_churn.tenure)
plt.show()
plt.hist(dsl_tel_churn.MonthlyCharges)
# Out:
# (array([151., 118., 213., 445., 381., 382., 236., 236., 175.,  84.]),
#  array([23.45 , 30.585, 37.72 , 44.855, 51.99 , 59.125, 66.26 , 73.395,
#         80.53 , 87.665, 94.8  ]),
#  <BarContainer object of 10 artists>)

# %%
dsl_tel_churn.plot.scatter('tenure','MonthlyCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
r,p = stats.spearmanr(dsl_tel_churn.tenure,dsl_tel_churn.MonthlyCharges)
r,p
# Out:
# (0.5197919467307187, 1.123536051364168e-167)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:1.123536051364168e-167

# %% [markdown]
# # fiber optic customers

# %%
fiber_tel_churn = tel_churn[tel_churn['InternetService'] == "Fiber optic"]

# %%
x3 = fiber_tel_churn.tenure
y3 = fiber_tel_churn.TotalCharges

# %% [markdown]
# # fiber Total

# %%
plt.hist(fiber_tel_churn.tenure)
plt.show()
plt.hist(fiber_tel_churn.TotalCharges)
# Out:
# (array([860., 378., 303., 249., 231., 248., 255., 229., 221., 122.]),
#  array([  68.5 ,  930.13, 1791.76, 2653.39, 3515.02, 4376.65, 5238.28,
#         6099.91, 6961.54, 7823.17, 8684.8 ]),
#  <BarContainer object of 10 artists>)

# %%
fiber_tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
r,p = stats.spearmanr(fiber_tel_churn.tenure,fiber_tel_churn.TotalCharges)
r,p
# Out:
# (0.9910979584930487, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %%
x6 = fiber_tel_churn.tenure
y6 = fiber_tel_churn.MonthlyCharges

# %% [markdown]
# # fiber monthly

# %%
fiber_tel_churn.plot.scatter('tenure','MonthlyCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
r,p = stats.spearmanr(fiber_tel_churn.tenure,fiber_tel_churn.MonthlyCharges)
r,p
# Out:
# (0.6279842911007443, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %% [markdown]
# # no internet

# %%
no_internt_tel_churn = tel_churn[tel_churn['InternetService'] == "No"]

# %% [markdown]
# # no internet total

# %%
no_internt_tel_churn.plot.scatter('tenure','TotalCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
r,p = stats.spearmanr(fiber_tel_churn.tenure,fiber_tel_churn.MonthlyCharges)
r,p
# Out:
# (0.6279842911007443, 0.0)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:0.0

# %% [markdown]
# # no internet monthly

# %%
plt.hist(no_internt_tel_churn.tenure)
plt.show()
plt.hist(no_internt_tel_churn.MonthlyCharges)
# Out:
# (array([ 54., 559., 513.,  58.,   0.,   6.,  58., 146., 109.,  23.]),
#  array([18.25 , 19.115, 19.98 , 20.845, 21.71 , 22.575, 23.44 , 24.305,
#         25.17 , 26.035, 26.9  ]),
#  <BarContainer object of 10 artists>)

# %%
no_internt_tel_churn.plot.scatter('tenure','MonthlyCharges', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
r,p = stats.spearmanr(no_internt_tel_churn.tenure,no_internt_tel_churn.MonthlyCharges)
r,p
# Out:
# (0.24136086041714058, 1.1491953364966684e-21)

# %%
 if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:1.1491953364966684e-21

# %% [markdown]
# # Use the employees database

# %%
from pydataset import data
from env import host, username, password

# %%
url = f'mysql+pymysql://{username}:{password}@{host}/employees'

# %%
 
emp_sal = pd.read_sql(
'''SELECT
DATEDIFF((SELECT MAX(hire_date) FROM employees), e.hire_date) AS tenure,
s.salary AS salary
FROM employees e
JOIN salaries s USING (emp_no)
WHERE s.to_date = '1999-01-01' ''', url)

# %%
emp_sal.head()
# Out:
#    tenure  salary
# 0    2193   47250
# 1    4273   83794
# 2    1261   50082
# 3    1265   60112
# 4    1338   40996

# %%
emp_title = pd.read_sql(
'''
SELECT
e.emp_no,
DATEDIFF((SELECT MAX(hire_date) FROM employees), e.hire_date) AS tenure,
ntitles
FROM employees e
JOIN (
SELECT emp_no, COUNT(*) as ntitles
FROM employees e
JOIN titles t USING (emp_no)
GROUP BY emp_no
) emp_title_count USING (emp_no)
''', url)

# %%
emp_title
# Out:
#         emp_no  tenure  ntitles
# 0        10001    4964        1
# 1        10002    5181        1
# 2        10003    4901        1
# 3        10004    4806        2
# 4        10005    3790        2
# ...        ...     ...      ...
# 300019  499995    2572        1
# 300020  499996    3410        2
# 300021  499997    5030        2
# 300022  499998    2298        2
# 300023  499999     789        1
#
# [300024 rows x 3 columns]

# %%
s.dtypes

# %% [markdown]
# # Is there a relationship between how long an employee has been with the company and their salary?

# %%
plt.hist(emp_sal.tenure)
plt.show()
plt.hist(emp_sal.salary)
# Out:
# (array([104., 126., 134., 106.,  66.,  65.,  38.,  27.,   6.,   4.]),
#  array([ 39586. ,  47570.7,  55555.4,  63540.1,  71524.8,  79509.5,
#          87494.2,  95478.9, 103463.6, 111448.3, 119433. ]),
#  <BarContainer object of 10 artists>)

# %%
emp_sal.plot.scatter('tenure','salary', c = "pink")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='salary'>

# %% [markdown]
# Ho = there is no linear relation
#
# Ha = there is a linear relation

# %%
r, p = stats.spearmanr(emp_sal.tenure, emp_sal.salary)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:1.8209482178149808e-16

# %%
x = s.from_date
y = s.salary

# %% [markdown]
# # Is there a relationship between how long an employee has been with the company and the number of titles they have had?

# %%
plt.hist(emp_title.tenure)
plt.show()
plt.hist(emp_title.ntitles)
# Out:
# (array([159754.,      0.,      0.,      0.,      0., 137256.,      0.,
#              0.,      0.,   3014.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
emp_title.plot.scatter('tenure', 'ntitles' )
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='ntitles'>

# %%
# num of titles is discrete, run anova or kruskall wallis

emp_title.tenure.var(),emp_title.ntitles.var()
# Out:
# (1655872.2657053773, 0.2695897496415161)

# %%
t, p = stats.kruskal(emp_title.ntitles,emp_title.tenure)
t, p
# Out:
# (464349.62293854164, 0.0)

# %%
p < alpha
# Out:
# True

# %%
#t,p = stats.spearmanr(emp_title.tenure, emp_title.ntitles)

# %% [markdown]
# # Use the sleepstudy data.

# %%
ss = data('sleepstudy')
ss.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %% [markdown]
# # Is there a relationship between days and reaction time?

# %%
ss.Days.var(),ss.Reaction.var()
# Out:
# (8.296089385474861, 3172.9288792737293)

# %%
# df.plot.scatter('coffee_consumed', 'exam_score')

# %%
ss.Days.hist()
plt.show()
ss.Reaction.hist()
# Out:
# <AxesSubplot:>

# %%
ss.plot.scatter('Days', 'Reaction', c = "black")
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>

# %%
r, p = stats.spearmanr(ss.Days,ss.Reaction)
r, p
# Out:
# (0.5228138502259547, 5.132878057706873e-14)

# %%
if p < alpha:
    print (f'reject null hypothesis. p value:{p}')
else:
    print( f"fail to reject. p value:{p}")
# Out:
# reject null hypothesis. p value:5.132878057706873e-14
